# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\fazal\anaconda3\envs\paythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\fazal\anaconda3\envs\paythondata\lib\site-packages (from citipy) (0.16)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add thelatitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
    # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description" : city_description                          
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gamba
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | san vicente
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | gambela
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | revelstoke
# Processing Record 10 of Set 1 | nhulunbuy
# Processing Record 11 of Set 1 | lae
# Processing Record 12 of Set 1 | anloga
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | mecca
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | port hardy
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | san patricio
# Processing Record 20 of Set 1 | isangel
# Processing Record 21 of Set 1 | igrim
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | coihaique
# Processing Record 25 of Set 1 | qiryat gat
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 1 | kytlym
# City not found. Skipping...
# Processing Record 33 of Set 1 | batemans bay
# Processing Record 34 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 1 | gravdal
# Processing Record 36 of Set 1 | vao
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | ginda
# Processing Record 44 of Set 1 | metro
# Processing Record 45 of Set 1 | nalut
# Processing Record 46 of Set 1 | kavaratti
# Processing Record 47 of Set 1 | russell
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | dwarka
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | rio gallegos
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | dali
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | talnakh
# Processing Record 8 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 2 | nicoya
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | ushtobe
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | poum
# Processing Record 14 of Set 2 | parvatsar
# Processing Record 15 of Set 2 | kholm-zhirkovskiy
# Processing Record 16 of Set 2 | guerrero negro
# Processing Record 17 of Set 2 | dakar
# Processing Record 18 of Set 2 | torbay
# Processing Record 19 of Set 2 | sorong
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 2 | birin
# Processing Record 23 of Set 2 | bubaque
# Processing Record 24 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | hofn
# Processing Record 27 of Set 2 | port blair
# Processing Record 28 of Set 2 | praia
# Processing Record 29 of Set 2 | ossora
# Processing Record 30 of Set 2 | shar
# Processing Record 31 of Set 2 | verkhnevilyuysk
# Processing Record 32 of Set 2 | harper
# Processing Record 33 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | korem
# Processing Record 36 of Set 2 | rio grande
# Processing Record 37 of Set 2 | vestmannaeyjar
# Processing Record 38 of Set 2 | olga
# Processing Record 39 of Set 2 | ransang
# Processing Record 40 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 2 | umm kaddadah
# Processing Record 42 of Set 2 | reconquista
# Processing Record 43 of Set 2 | kaitangata
# Processing Record 44 of Set 2 | simi valley
# Processing Record 45 of Set 2 | andevoranto
# City not found. Skipping...
# Processing Record 46 of Set 2 | kudahuvadhoo
# Processing Record 47 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | pervomayskiy
# Processing Record 50 of Set 2 | biak
# Processing Record 1 of Set 3 | mataura
# Processing Record 2 of Set 3 | cegled
# Processing Record 3 of Set 3 | gizo
# Processing Record 4 of Set 3 | aklavik
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | doctor juan leon mallorquin
# Processing Record 8 of Set 3 | plettenberg
# Processing Record 9 of Set 3 | zverinogolovskoye
# Processing Record 10 of Set 3 | altay
# Processing Record 11 of Set 3 | provideniya
# Processing Record 12 of Set 3 | labuhan
# Processing Record 13 of Set 3 | port lincoln
# Processing Record 14 of Set 3 | atar
# Processing Record 15 of Set 3 | tarko-sale
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | khatanga
# Processing Record 22 of Set 3 | souillac
# Processing Record 23 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 3 | bethel
# Processing Record 25 of Set 3 | jumla
# Processing Record 26 of Set 3 | beringovskiy
# Processing Record 27 of Set 3 | praia da vitoria
# Processing Record 28 of Set 3 | mayo
# Processing Record 29 of Set 3 | sabang
# Processing Record 30 of Set 3 | sao joao da barra
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | kargasok
# Processing Record 33 of Set 3 | sao filipe
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | tuatapere
# Processing Record 36 of Set 3 | caucaia
# Processing Record 37 of Set 3 | erzin
# Processing Record 38 of Set 3 | den helder
# Processing Record 39 of Set 3 | moba
# Processing Record 40 of Set 3 | karema
# Processing Record 41 of Set 3 | yelkhovka
# Processing Record 42 of Set 3 | naron
# Processing Record 43 of Set 3 | palmer
# Processing Record 44 of Set 3 | upernavik
# Processing Record 45 of Set 3 | nantucket
# Processing Record 46 of Set 3 | faya
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | garowe
# Processing Record 49 of Set 3 | jasper
# Processing Record 50 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 4 | grindavik
# Processing Record 2 of Set 4 | hasaki
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | micheweni
# Processing Record 6 of Set 4 | vardo
# Processing Record 7 of Set 4 | luderitz
# Processing Record 8 of Set 4 | zhigansk
# Processing Record 9 of Set 4 | yellowknife
# Processing Record 10 of Set 4 | bose
# Processing Record 11 of Set 4 | bilibino
# Processing Record 12 of Set 4 | izumo
# Processing Record 13 of Set 4 | zhanakorgan
# Processing Record 14 of Set 4 | mogadishu
# Processing Record 15 of Set 4 | quatre cocos
# Processing Record 16 of Set 4 | shenjiamen
# Processing Record 17 of Set 4 | southbridge
# Processing Record 18 of Set 4 | eunice
# Processing Record 19 of Set 4 | cherskiy
# Processing Record 20 of Set 4 | zaanstad
# Processing Record 21 of Set 4 | tiarei
# Processing Record 22 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 4 | santa isabel do rio negro
# Processing Record 24 of Set 4 | vila franca do campo
# Processing Record 25 of Set 4 | pevek
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | praya
# Processing Record 28 of Set 4 | srednekolymsk
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | basavana bagevadi
# Processing Record 31 of Set 4 | spasskoye
# Processing Record 32 of Set 4 | wewak
# Processing Record 33 of Set 4 | kuytun
# Processing Record 34 of Set 4 | otane
# Processing Record 35 of Set 4 | port-gentil
# Processing Record 36 of Set 4 | saint-pierre
# Processing Record 37 of Set 4 | san ignacio
# Processing Record 38 of Set 4 | berlevag
# Processing Record 39 of Set 4 | labrea
# Processing Record 40 of Set 4 | shahr-e kord
# Processing Record 41 of Set 4 | vaini
# Processing Record 42 of Set 4 | hualmay
# Processing Record 43 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 4 | severo-kurilsk
# Processing Record 45 of Set 4 | itarema
# Processing Record 46 of Set 4 | hambantota
# Processing Record 47 of Set 4 | bayeux
# Processing Record 48 of Set 4 | kiama
# Processing Record 49 of Set 4 | mount isa
# Processing Record 50 of Set 4 | athabasca
# Processing Record 1 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 2 of Set 5 | saint george
# Processing Record 3 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 5 | phichit
# Processing Record 5 of Set 5 | touros
# Processing Record 6 of Set 5 | paamiut
# Processing Record 7 of Set 5 | camargo
# Processing Record 8 of Set 5 | kuito
# Processing Record 9 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | empalme
# Processing Record 12 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 5 | ngunguru
# Processing Record 14 of Set 5 | samdrup jongkhar
# Processing Record 15 of Set 5 | cayenne
# Processing Record 16 of Set 5 | bengkulu
# Processing Record 17 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 5 | saldanha
# Processing Record 19 of Set 5 | huarmey
# Processing Record 20 of Set 5 | portland
# Processing Record 21 of Set 5 | miraflores
# Processing Record 22 of Set 5 | kailua
# Processing Record 23 of Set 5 | malumfashi
# Processing Record 24 of Set 5 | evensk
# Processing Record 25 of Set 5 | ashqelon
# Processing Record 26 of Set 5 | katsuura
# Processing Record 27 of Set 5 | clyde river
# Processing Record 28 of Set 5 | dunedin
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | kahului
# Processing Record 31 of Set 5 | marsh harbour
# Processing Record 32 of Set 5 | bandarbeyla
# Processing Record 33 of Set 5 | takoradi
# Processing Record 34 of Set 5 | chuy
# Processing Record 35 of Set 5 | ruwi
# Processing Record 36 of Set 5 | ottumwa
# Processing Record 37 of Set 5 | musiri
# Processing Record 38 of Set 5 | manta
# Processing Record 39 of Set 5 | youghal
# Processing Record 40 of Set 5 | tobermory
# Processing Record 41 of Set 5 | lubao
# Processing Record 42 of Set 5 | svetlogorsk
# Processing Record 43 of Set 5 | todos santos
# Processing Record 44 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 5 | araouane
# Processing Record 46 of Set 5 | mtambile
# Processing Record 47 of Set 5 | aswan
# Processing Record 48 of Set 5 | nerchinskiy zavod
# Processing Record 49 of Set 5 | dortyol
# Processing Record 50 of Set 5 | hovd
# Processing Record 1 of Set 6 | palauig
# Processing Record 2 of Set 6 | ponta do sol
# Processing Record 3 of Set 6 | nizhniy tsasuchey
# Processing Record 4 of Set 6 | oranjemund
# Processing Record 5 of Set 6 | kelowna
# Processing Record 6 of Set 6 | machali
# Processing Record 7 of Set 6 | narsaq
# Processing Record 8 of Set 6 | crisan
# Processing Record 9 of Set 6 | sobolevo
# Processing Record 10 of Set 6 | saskylakh
# Processing Record 11 of Set 6 | haines junction
# Processing Record 12 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 6 | seoul
# Processing Record 14 of Set 6 | avera
# Processing Record 15 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 6 | progreso
# Processing Record 17 of Set 6 | gubkinskiy
# Processing Record 18 of Set 6 | obo
# Processing Record 19 of Set 6 | oranjestad
# Processing Record 20 of Set 6 | beloha
# Processing Record 21 of Set 6 | samarai
# Processing Record 22 of Set 6 | det udom
# Processing Record 23 of Set 6 | sept-iles
# Processing Record 24 of Set 6 | antofagasta
# Processing Record 25 of Set 6 | saint-augustin
# Processing Record 26 of Set 6 | nabire
# Processing Record 27 of Set 6 | umuarama
# Processing Record 28 of Set 6 | dori
# Processing Record 29 of Set 6 | meulaboh
# Processing Record 30 of Set 6 | chissamba
# Processing Record 31 of Set 6 | fairview
# Processing Record 32 of Set 6 | waddan
# Processing Record 33 of Set 6 | yeniseysk
# Processing Record 34 of Set 6 | sembe
# Processing Record 35 of Set 6 | longyearbyen
# Processing Record 36 of Set 6 | college
# Processing Record 37 of Set 6 | khorixas
# Processing Record 38 of Set 6 | sidi ali
# Processing Record 39 of Set 6 | north bend
# Processing Record 40 of Set 6 | orsha
# Processing Record 41 of Set 6 | svetlaya
# Processing Record 42 of Set 6 | kirakira
# Processing Record 43 of Set 6 | vanderhoof
# Processing Record 44 of Set 6 | severnoye
# Processing Record 45 of Set 6 | lumberton
# Processing Record 46 of Set 6 | kachikau
# City not found. Skipping...
# Processing Record 47 of Set 6 | neiafu
# Processing Record 48 of Set 6 | padang
# Processing Record 49 of Set 6 | ostrovnoy
# Processing Record 50 of Set 6 | cidreira
# Processing Record 1 of Set 7 | misratah
# Processing Record 2 of Set 7 | odweyne
# Processing Record 3 of Set 7 | churumuco
# City not found. Skipping...
# Processing Record 4 of Set 7 | puri
# Processing Record 5 of Set 7 | barrow
# Processing Record 6 of Set 7 | urumqi
# Processing Record 7 of Set 7 | oreanda
# City not found. Skipping...
# Processing Record 8 of Set 7 | sola
# Processing Record 9 of Set 7 | borovoy
# Processing Record 10 of Set 7 | alice springs
# Processing Record 11 of Set 7 | gainesville
# Processing Record 12 of Set 7 | rocha
# Processing Record 13 of Set 7 | dossor
# Processing Record 14 of Set 7 | banjar
# Processing Record 15 of Set 7 | ahipara
# Processing Record 16 of Set 7 | ukiah
# Processing Record 17 of Set 7 | gat
# Processing Record 18 of Set 7 | nelson bay
# Processing Record 19 of Set 7 | zhezkazgan
# Processing Record 20 of Set 7 | manadhoo
# Processing Record 21 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 7 | ginir
# Processing Record 23 of Set 7 | beisfjord
# Processing Record 24 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 7 | whitehorse
# Processing Record 26 of Set 7 | atambua
# Processing Record 27 of Set 7 | carutapera
# Processing Record 28 of Set 7 | scarborough
# Processing Record 29 of Set 7 | iqaluit
# Processing Record 30 of Set 7 | geraldton
# Processing Record 31 of Set 7 | jining
# Processing Record 32 of Set 7 | bend
# Processing Record 33 of Set 7 | roswell
# Processing Record 34 of Set 7 | pingliang
# Processing Record 35 of Set 7 | kruisfontein
# Processing Record 36 of Set 7 | xai-xai
# Processing Record 37 of Set 7 | nizhnevartovsk
# Processing Record 38 of Set 7 | sinnamary
# Processing Record 39 of Set 7 | songea
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | zlotoryja
# Processing Record 42 of Set 7 | stornoway
# Processing Record 43 of Set 7 | majene
# Processing Record 44 of Set 7 | dong xoai
# Processing Record 45 of Set 7 | kurilsk
# Processing Record 46 of Set 7 | linfen
# Processing Record 47 of Set 7 | tutoia
# Processing Record 48 of Set 7 | general roca
# Processing Record 49 of Set 7 | ternate
# Processing Record 50 of Set 7 | rawson
# Processing Record 1 of Set 8 | nova varos
# Processing Record 2 of Set 8 | karachi
# Processing Record 3 of Set 8 | ancud
# Processing Record 4 of Set 8 | mount gambier
# Processing Record 5 of Set 8 | carora
# Processing Record 6 of Set 8 | mpika
# Processing Record 7 of Set 8 | belyy yar
# Processing Record 8 of Set 8 | estelle
# Processing Record 9 of Set 8 | itacare
# Processing Record 10 of Set 8 | victoria
# Processing Record 11 of Set 8 | saint-andre-lez-lille
# Processing Record 12 of Set 8 | nautla
# Processing Record 13 of Set 8 | roald
# Processing Record 14 of Set 8 | belmonte
# Processing Record 15 of Set 8 | westport
# Processing Record 16 of Set 8 | maine-soroa
# Processing Record 17 of Set 8 | kavieng
# Processing Record 18 of Set 8 | kohila
# Processing Record 19 of Set 8 | aubenas
# Processing Record 20 of Set 8 | te anau
# Processing Record 21 of Set 8 | freeport
# Processing Record 22 of Set 8 | havelock
# Processing Record 23 of Set 8 | khani
# Processing Record 24 of Set 8 | muromtsevo
# Processing Record 25 of Set 8 | cravo norte
# Processing Record 26 of Set 8 | cheremshanka
# Processing Record 27 of Set 8 | nagato
# Processing Record 28 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 8 | lixourion
# Processing Record 30 of Set 8 | komsomolskiy
# Processing Record 31 of Set 8 | yulara
# Processing Record 32 of Set 8 | hervey bay
# Processing Record 33 of Set 8 | naze
# Processing Record 34 of Set 8 | anadyr
# Processing Record 35 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 8 | tecoanapa
# Processing Record 37 of Set 8 | tabuk
# Processing Record 38 of Set 8 | nanortalik
# Processing Record 39 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 40 of Set 8 | kawalu
# Processing Record 41 of Set 8 | piacabucu
# Processing Record 42 of Set 8 | khandbari
# Processing Record 43 of Set 8 | rayong
# Processing Record 44 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 8 | comodoro rivadavia
# Processing Record 46 of Set 8 | shumskiy
# Processing Record 47 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 8 | sitka
# Processing Record 49 of Set 8 | honiara
# Processing Record 50 of Set 8 | husavik
# Processing Record 1 of Set 9 | villa carlos paz
# Processing Record 2 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 3 of Set 9 | mayya
# Processing Record 4 of Set 9 | the valley
# Processing Record 5 of Set 9 | ridgecrest
# Processing Record 6 of Set 9 | kindu
# Processing Record 7 of Set 9 | bilgoraj
# Processing Record 8 of Set 9 | ambon
# Processing Record 9 of Set 9 | xichang
# Processing Record 10 of Set 9 | vila do maio
# Processing Record 11 of Set 9 | nova granada
# Processing Record 12 of Set 9 | guymon
# Processing Record 13 of Set 9 | pangai
# Processing Record 14 of Set 9 | ericeira
# Processing Record 15 of Set 9 | sakakah
# Processing Record 16 of Set 9 | blackwater
# Processing Record 17 of Set 9 | thurso
# Processing Record 18 of Set 9 | tamale
# Processing Record 19 of Set 9 | buraydah
# Processing Record 20 of Set 9 | hami
# Processing Record 21 of Set 9 | namibe
# Processing Record 22 of Set 9 | nemuro
# Processing Record 23 of Set 9 | inhambane
# Processing Record 24 of Set 9 | skibbereen
# Processing Record 25 of Set 9 | broome
# Processing Record 26 of Set 9 | sovetskoye
# Processing Record 27 of Set 9 | esperance
# Processing Record 28 of Set 9 | belize
# Processing Record 29 of Set 9 | mackenzie
# Processing Record 30 of Set 9 | barabai
# Processing Record 31 of Set 9 | lucea
# Processing Record 32 of Set 9 | pittsfield
# Processing Record 33 of Set 9 | scottsbluff
# Processing Record 34 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 35 of Set 9 | wufeng
# Processing Record 36 of Set 9 | aksarka
# Processing Record 37 of Set 9 | las cruces
# Processing Record 38 of Set 9 | jinchang
# Processing Record 39 of Set 9 | changping
# Processing Record 40 of Set 9 | fort wellington
# Processing Record 41 of Set 9 | narok
# Processing Record 42 of Set 9 | krasnoselkup
# Processing Record 43 of Set 9 | namanga
# Processing Record 44 of Set 9 | taonan
# Processing Record 45 of Set 9 | bonito
# Processing Record 46 of Set 9 | hobyo
# Processing Record 47 of Set 9 | soure
# Processing Record 48 of Set 9 | ilhabela
# Processing Record 49 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 9 | wanning
# Processing Record 1 of Set 10 | tetelzingo
# Processing Record 2 of Set 10 | malakal
# Processing Record 3 of Set 10 | safford
# Processing Record 4 of Set 10 | namatanai
# Processing Record 5 of Set 10 | lorengau
# Processing Record 6 of Set 10 | deputatskiy
# Processing Record 7 of Set 10 | leshukonskoye
# Processing Record 8 of Set 10 | fortuna
# Processing Record 9 of Set 10 | bell ville
# Processing Record 10 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 10 | iquique
# Processing Record 12 of Set 10 | jamiltepec
# Processing Record 13 of Set 10 | taksimo
# Processing Record 14 of Set 10 | necochea
# Processing Record 15 of Set 10 | mugur-aksy
# Processing Record 16 of Set 10 | fort saint james
# Processing Record 17 of Set 10 | selenginsk
# Processing Record 18 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 10 | los llanos de aridane
# Processing Record 20 of Set 10 | jiazi
# Processing Record 21 of Set 10 | hay river
# Processing Record 22 of Set 10 | okhotsk
# Processing Record 23 of Set 10 | novaya igirma
# Processing Record 24 of Set 10 | porto novo
# Processing Record 25 of Set 10 | pimentel
# Processing Record 26 of Set 10 | sinop
# Processing Record 27 of Set 10 | talara
# Processing Record 28 of Set 10 | thinadhoo
# Processing Record 29 of Set 10 | bac lieu
# Processing Record 30 of Set 10 | yumen
# Processing Record 31 of Set 10 | saint-andre-les-vergers
# Processing Record 32 of Set 10 | novoutkinsk
# Processing Record 33 of Set 10 | sistranda
# Processing Record 34 of Set 10 | erenhot
# Processing Record 35 of Set 10 | korla
# Processing Record 36 of Set 10 | parras
# City not found. Skipping...
# Processing Record 37 of Set 10 | blagoveshchenka
# Processing Record 38 of Set 10 | batagay-alyta
# Processing Record 39 of Set 10 | makushino
# Processing Record 40 of Set 10 | tautira
# Processing Record 41 of Set 10 | mehamn
# Processing Record 42 of Set 10 | ixtapa
# Processing Record 43 of Set 10 | kingsland
# Processing Record 44 of Set 10 | aksarayskiy
# Processing Record 45 of Set 10 | saraland
# Processing Record 46 of Set 10 | acarau
# Processing Record 47 of Set 10 | eureka
# Processing Record 48 of Set 10 | mufumbwe
# Processing Record 49 of Set 10 | manicaragua
# Processing Record 50 of Set 10 | lichtenburg
# Processing Record 1 of Set 11 | mandera
# Processing Record 2 of Set 11 | kasamwa
# Processing Record 3 of Set 11 | soeng sang
# Processing Record 4 of Set 11 | yerbogachen
# Processing Record 5 of Set 11 | rio branco
# Processing Record 6 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 11 | kitimat
# Processing Record 8 of Set 11 | zabol
# Processing Record 9 of Set 11 | vikulovo
# Processing Record 10 of Set 11 | canakkale
# Processing Record 11 of Set 11 | dzhebariki-khaya
# Processing Record 12 of Set 11 | dauphin
# Processing Record 13 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 14 of Set 11 | balikpapan
# Processing Record 15 of Set 11 | ziarat
# Processing Record 16 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 11 | romblon
# Processing Record 18 of Set 11 | otradnoye
# Processing Record 19 of Set 11 | elbistan
# Processing Record 20 of Set 11 | lavrentiya
# Processing Record 21 of Set 11 | kidal
# Processing Record 22 of Set 11 | lewistown
# Processing Record 23 of Set 11 | taoudenni
# Processing Record 24 of Set 11 | yelizovo
# Processing Record 25 of Set 11 | adrar
# Processing Record 26 of Set 11 | fort nelson
# Processing Record 27 of Set 11 | ishim
# Processing Record 28 of Set 11 | maniitsoq
# Processing Record 29 of Set 11 | japura
# Processing Record 30 of Set 11 | qandala
# Processing Record 31 of Set 11 | talcahuano
# Processing Record 32 of Set 11 | shingu
# Processing Record 33 of Set 11 | bataipora
# Processing Record 34 of Set 11 | jieshi
# Processing Record 35 of Set 11 | fare
# Processing Record 36 of Set 11 | nouadhibou
# Processing Record 37 of Set 11 | dicabisagan
# Processing Record 38 of Set 11 | alofi
# Processing Record 39 of Set 11 | koyilandi
# City not found. Skipping...
# Processing Record 40 of Set 11 | linares
# Processing Record 41 of Set 11 | west bay
# Processing Record 42 of Set 11 | ranong
# Processing Record 43 of Set 11 | kulhudhuffushi
# Processing Record 44 of Set 11 | kodinsk
# Processing Record 45 of Set 11 | hacari
# Processing Record 46 of Set 11 | tual
# Processing Record 47 of Set 11 | nome
# Processing Record 48 of Set 11 | astoria
# Processing Record 49 of Set 11 | salto
# Processing Record 50 of Set 11 | andijon
# Processing Record 1 of Set 12 | jiangkou
# Processing Record 2 of Set 12 | moindou
# Processing Record 3 of Set 12 | birao
# Processing Record 4 of Set 12 | kichera
# Processing Record 5 of Set 12 | vostok
# Processing Record 6 of Set 12 | krasnoarmeyskoye
# Processing Record 7 of Set 12 | payson
# Processing Record 8 of Set 12 | beitbridge
# Processing Record 9 of Set 12 | atbasar
# Processing Record 10 of Set 12 | ulaangom
# Processing Record 11 of Set 12 | sungaipenuh
# Processing Record 12 of Set 12 | bacabal
# Processing Record 13 of Set 12 | belaya gora
# Processing Record 14 of Set 12 | koutiala
# Processing Record 15 of Set 12 | hirara
# Processing Record 16 of Set 12 | amahai
# Processing Record 17 of Set 12 | ewa beach
# Processing Record 18 of Set 12 | pitimbu
# Processing Record 19 of Set 12 | stawell
# Processing Record 20 of Set 12 | apiai
# Processing Record 21 of Set 12 | smithers
# Processing Record 22 of Set 12 | ust-nera
# Processing Record 23 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 12 | tuytepa
# Processing Record 25 of Set 12 | falam
# Processing Record 26 of Set 12 | hopkinsville
# Processing Record 27 of Set 12 | petropavl
# Processing Record 28 of Set 12 | qaqortoq
# Processing Record 29 of Set 12 | dombarovskiy
# Processing Record 30 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 31 of Set 12 | nizhniy kuranakh
# Processing Record 32 of Set 12 | havoysund
# Processing Record 33 of Set 12 | coos bay
# Processing Record 34 of Set 12 | tocantinopolis
# City not found. Skipping...
# Processing Record 35 of Set 12 | muli
# Processing Record 36 of Set 12 | poltava
# Processing Record 37 of Set 12 | golden
# Processing Record 38 of Set 12 | adre
# Processing Record 39 of Set 12 | feni
# Processing Record 40 of Set 12 | constitucion
# Processing Record 41 of Set 12 | moose factory
# Processing Record 42 of Set 12 | hamilton
# Processing Record 43 of Set 12 | pangnirtung
# Processing Record 44 of Set 12 | ilulissat
# Processing Record 45 of Set 12 | corinto
# Processing Record 46 of Set 12 | devarkonda
# Processing Record 47 of Set 12 | pedasi
# Processing Record 48 of Set 12 | kalabo
# Processing Record 49 of Set 12 | tessalit
# Processing Record 50 of Set 12 | westminster
# Processing Record 1 of Set 13 | yangambi
# Processing Record 2 of Set 13 | gbarnga
# Processing Record 3 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 13 | codrington
# Processing Record 5 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 13 | bathsheba
# Processing Record 7 of Set 13 | ereymentau
# Processing Record 8 of Set 13 | bambous virieux
# Processing Record 9 of Set 13 | bardiyah
# Processing Record 10 of Set 13 | lere
# Processing Record 11 of Set 13 | port hedland
# Processing Record 12 of Set 13 | tarakan
# Processing Record 13 of Set 13 | santa cruz de la palma
# Processing Record 14 of Set 13 | nara
# Processing Record 15 of Set 13 | ferrol
# Processing Record 16 of Set 13 | calatayud
# Processing Record 17 of Set 13 | thunder bay
# Processing Record 18 of Set 13 | nuuk
# Processing Record 19 of Set 13 | maun
# Processing Record 20 of Set 13 | lagoa
# Processing Record 21 of Set 13 | coquimbo
# Processing Record 22 of Set 13 | ancona
# Processing Record 23 of Set 13 | orangeburg
# Processing Record 24 of Set 13 | linden
# Processing Record 25 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record 26 of Set 13 | palora
# Processing Record 27 of Set 13 | ji-parana
# City not found. Skipping...
# Processing Record 28 of Set 13 | estepona
# Processing Record 29 of Set 13 | cockburn town
# Processing Record 30 of Set 13 | la ronge
# Processing Record 31 of Set 13 | muros
# Processing Record 32 of Set 13 | bonavista
# Processing Record 33 of Set 13 | george
# Processing Record 34 of Set 13 | mossendjo
# Processing Record 35 of Set 13 | matagami
# Processing Record 36 of Set 13 | cap-aux-meules
# Processing Record 37 of Set 13 | burnie
# Processing Record 38 of Set 13 | ayan
# Processing Record 39 of Set 13 | karwar
# Processing Record 40 of Set 13 | tsaratanana
# Processing Record 41 of Set 13 | luwuk
# Processing Record 42 of Set 13 | sassandra
# Processing Record 43 of Set 13 | challans
# Processing Record 44 of Set 13 | klaksvik
# Processing Record 45 of Set 13 | barahona
# Processing Record 46 of Set 13 | tucuman
# Processing Record 47 of Set 13 | wanlaweyn
# Processing Record 48 of Set 13 | saint andrews
# Processing Record 49 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 13 | gogrial
# Processing Record 1 of Set 14 | karratha
# Processing Record 2 of Set 14 | lerwick
# Processing Record 3 of Set 14 | centerville
# Processing Record 4 of Set 14 | pringsewu
# Processing Record 5 of Set 14 | riyadh
# Processing Record 6 of Set 14 | bayir
# Processing Record 7 of Set 14 | yecla
# Processing Record 8 of Set 14 | campbell river
# Processing Record 9 of Set 14 | wanaka
# Processing Record 10 of Set 14 | arroyo
# Processing Record 11 of Set 14 | sydney
# Processing Record 12 of Set 14 | witu
# Processing Record 13 of Set 14 | katangli
# Processing Record 14 of Set 14 | sochi
# Processing Record 15 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 14 | bentiu
# Processing Record 17 of Set 14 | aspindza
# Processing Record 18 of Set 14 | mandalgovi
# Processing Record 19 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 20 of Set 14 | lupiro
# Processing Record 21 of Set 14 | si sa ket
# Processing Record 22 of Set 14 | talca
# Processing Record 23 of Set 14 | sibu
# Processing Record 24 of Set 14 | rexburg
# Processing Record 25 of Set 14 | marzuq
# Processing Record 26 of Set 14 | linxia
# Processing Record 27 of Set 14 | obigarm
# Processing Record 28 of Set 14 | chegutu
# Processing Record 29 of Set 14 | raga
# Processing Record 30 of Set 14 | tshikapa
# Processing Record 31 of Set 14 | lisakovsk
# Processing Record 32 of Set 14 | livingston
# Processing Record 33 of Set 14 | marystown
# Processing Record 34 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 14 | kaeo
# Processing Record 36 of Set 14 | pisco
# Processing Record 37 of Set 14 | ballina
# Processing Record 38 of Set 14 | tahta
# Processing Record 39 of Set 14 | vanimo
# Processing Record 40 of Set 14 | mae sot
# Processing Record 41 of Set 14 | venado tuerto
# Processing Record 42 of Set 14 | hangu
# Processing Record 43 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 14 | omboue
# Processing Record 45 of Set 14 | chhatarpur
# Processing Record 46 of Set 14 | chandler
# Processing Record 47 of Set 14 | licheng
# Processing Record 48 of Set 14 | sucre
# Processing Record 49 of Set 14 | dickinson
# Processing Record 50 of Set 14 | bud
# Processing Record 1 of Set 15 | kontagora
# Processing Record 2 of Set 15 | noumea
# Processing Record 3 of Set 15 | tomigusuku
# Processing Record 4 of Set 15 | xuchang
# Processing Record 5 of Set 15 | arica
# Processing Record 6 of Set 15 | simplicio mendes
# Processing Record 7 of Set 15 | northam
# Processing Record 8 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 15 | san carlos de bariloche
# Processing Record 10 of Set 15 | villa union
# Processing Record 11 of Set 15 | szczytno
# Processing Record 12 of Set 15 | batagay
# Processing Record 13 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 15 | half moon bay
# Processing Record 16 of Set 15 | broken hill
# Processing Record 17 of Set 15 | santa isabel
# Processing Record 18 of Set 15 | gardan diwal
# City not found. Skipping...
# Processing Record 19 of Set 15 | awjilah
# Processing Record 20 of Set 15 | burica
# City not found. Skipping...
# Processing Record 21 of Set 15 | antalaha
# Processing Record 22 of Set 15 | brae
# Processing Record 23 of Set 15 | kawerau
# Processing Record 24 of Set 15 | noyabrsk
# Processing Record 25 of Set 15 | bassano
# Processing Record 26 of Set 15 | river falls
# Processing Record 27 of Set 15 | afmadu
# City not found. Skipping...
# Processing Record 28 of Set 15 | jalu
# Processing Record 29 of Set 15 | newport
# Processing Record 30 of Set 15 | shahrud
# Processing Record 31 of Set 15 | fernley
# Processing Record 32 of Set 15 | mangan
# Processing Record 33 of Set 15 | muyezerskiy
# Processing Record 34 of Set 15 | ta khmau
# Processing Record 35 of Set 15 | magadan
# Processing Record 36 of Set 15 | khandyga
# Processing Record 37 of Set 15 | harwich
# Processing Record 38 of Set 15 | rabo de peixe
# Processing Record 39 of Set 15 | mananjary
# Processing Record 40 of Set 15 | leningradskiy
# Processing Record 41 of Set 15 | grootfontein
# Processing Record 42 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 43 of Set 15 | naryan-mar
# Processing Record 44 of Set 15 | dongning
# Processing Record 45 of Set 15 | tortoli
# Processing Record 46 of Set 15 | dodge city
# Processing Record 47 of Set 15 | havre-saint-pierre
# Processing Record 48 of Set 15 | sao gabriel da cachoeira
# Processing Record 49 of Set 15 | san cristobal
# Processing Record 50 of Set 15 | dunmore east
# Processing Record 1 of Set 16 | longyan
# Processing Record 2 of Set 16 | tankara
# Processing Record 3 of Set 16 | pouebo
# Processing Record 4 of Set 16 | raudeberg
# Processing Record 5 of Set 16 | sao goncalo do amarante
# Processing Record 6 of Set 16 | roebourne
# Processing Record 7 of Set 16 | mut
# Processing Record 8 of Set 16 | aginskoye
# Processing Record 9 of Set 16 | nanakuli
# Processing Record 10 of Set 16 | zhob
# Processing Record 11 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 16 | mokrous
# Processing Record 13 of Set 16 | buchanan
# Processing Record 14 of Set 16 | sangar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Gamba      GA  -2.6500   10.0000     74.32        94         100
# 1      Nikolskoye      RU  59.7035   30.7861     25.39        91         100
# 2     San Vicente      AR -26.6167  -54.1333     70.41        59         100
# 3          Dikson      RU  73.5069   80.5464    -13.59        83         100
# 4    Punta Arenas      CL -53.1500  -70.9167     50.11        81           0
# 5         Gambela      ET   8.2500   34.5833     73.65        35          35
# 6  Port Elizabeth      ZA -33.9180   25.5701     66.49        72          90
# 7          Faanui      PF -16.4833 -151.7500     80.47        72          75
# 8      Revelstoke      CA  50.9832 -118.2023     32.02       100          90
# 9       Nhulunbuy      AU -12.2333  136.7667     95.61        49          40
#
#    Wind Speed       Description
# 0        2.57        light rain
# 1        7.27   overcast clouds
# 2        3.71   overcast clouds
# 3        6.29   overcast clouds
# 4        3.44         clear sky
# 5        3.38  scattered clouds
# 6        3.44   overcast clouds
# 7        6.38        light rain
# 8        0.00        light rain
# 9        9.22  scattered clouds

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv("WeatherPy_Database.csv",index_label="City_ID")
